# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Laptop World\Building_Energy_Twin_Sequential_3Years.csv", parse_dates=['Timestamp'], index_col='Timestamp')

print("Shape:")
print(df.shape)

print("\nHead:")
print(df.head())

print("\nDescribe:")
print(df.describe())

print("\nColumns:")
print(df.columns.tolist())

print("\nMissing Values:")
print(df.isnull().sum())

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Laptop World\Building_Energy_Twin_Sequential_3Years.csv", parse_dates=['Timestamp'], index_col='Timestamp')

corr = df.corr()['Total_Energy_Wh'].sort_values(ascending=False)
print("Correlation with Total_Energy_Wh:")
print(corr)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Laptop World\Building_Energy_Twin_Sequential_3Years.csv", parse_dates=['Timestamp'], index_col='Timestamp')

plt.figure(figsize=(20, 16))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Full Correlation Matrix')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Laptop World\Building_Energy_Twin_Sequential_3Years.csv", parse_dates=['Timestamp'], index_col='Timestamp')

plt.figure(figsize=(14, 6))
df['Total_Energy_Wh'].resample('M').mean().plot()
plt.title('Monthly Average Total Energy')
plt.ylabel('Wh')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Laptop World\Building_Energy_Twin_Sequential_3Years.csv", parse_dates=['Timestamp'], index_col='Timestamp')

plt.figure(figsize=(12, 6))
df.groupby('Hour')['Total_Energy_Wh'].mean().plot(kind='bar')
plt.title('Average Total Energy by Hour of Day')
plt.ylabel('Wh')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Laptop World\Building_Energy_Twin_Sequential_3Years.csv", parse_dates=['Timestamp'], index_col='Timestamp')

plt.figure(figsize=(12, 6))
df.groupby('Day_of_Week')['Total_Energy_Wh'].mean().plot(kind='bar')
plt.title('Average Total Energy by Day of Week (0=Monday)')
plt.ylabel('Wh')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Laptop World\Building_Energy_Twin_Sequential_3Years.csv", parse_dates=['Timestamp'], index_col='Timestamp')

plt.figure(figsize=(12, 6))
df.groupby('Season')['Total_Energy_Wh'].mean().plot(kind='bar')
plt.title('Average Total Energy by Season')
plt.ylabel('Wh')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Laptop World\Building_Energy_Twin_Sequential_3Years.csv", parse_dates=['Timestamp'], index_col='Timestamp')

plt.figure(figsize=(12, 6))
sns.boxplot(x='Is_Weekend', y='Total_Energy_Wh', data=df)
plt.title('Total Energy: Weekday vs Weekend')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Laptop World\Building_Energy_Twin_Sequential_3Years.csv", parse_dates=['Timestamp'], index_col='Timestamp')

plt.figure(figsize=(12, 6))
sns.scatterplot(x='OutsideWeather_Temp_C', y='Total_Energy_Wh', data=df.sample(5000), alpha=0.5)
plt.title('Outdoor Temperature vs Total Energy')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Laptop World\Building_Energy_Twin_Sequential_3Years.csv", parse_dates=['Timestamp'], index_col='Timestamp')

plt.figure(figsize=(12, 6))
sns.scatterplot(x='Total_Occupancy_Count', y='Total_Energy_Wh', data=df.sample(5000), alpha=0.5)
plt.title('Occupancy vs Total Energy')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Laptop World\Building_Energy_Twin_Sequential_3Years.csv", parse_dates=['Timestamp'], index_col='Timestamp')

plt.figure(figsize=(12, 6))
df[['Energy_HVAC_Wh', 'Energy_Lighting_Wh', 'Energy_Plug_Wh', 'Energy_Other_Wh']].mean().plot(kind='bar')
plt.title('Average End-Use Consumption')
plt.ylabel('Wh')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Laptop World\Building_Energy_Twin_Sequential_3Years.csv", parse_dates=['Timestamp'], index_col='Timestamp')

plt.figure(figsize=(12, 6))
df.groupby('Hour')['Energy_HVAC_Wh'].mean().plot(kind='line')
plt.title('Average HVAC by Hour')
plt.ylabel('Wh')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Laptop World\Building_Energy_Twin_Sequential_3Years.csv", parse_dates=['Timestamp'], index_col='Timestamp')

plt.figure(figsize=(12, 6))
df.groupby('Hour')['Energy_Lighting_Wh'].mean().plot(kind='line')
plt.title('Average Lighting by Hour')
plt.ylabel('Wh')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Laptop World\Building_Energy_Twin_Sequential_3Years.csv", parse_dates=['Timestamp'], index_col='Timestamp')

plt.figure(figsize=(12, 6))
df.groupby('Hour')['Energy_Plug_Wh'].mean().plot(kind='line')
plt.title('Average Plug by Hour')
plt.ylabel('Wh')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Laptop World\Building_Energy_Twin_Sequential_3Years.csv", parse_dates=['Timestamp'], index_col='Timestamp')

plt.figure(figsize=(12, 6))
sns.histplot(df['Total_Energy_Wh'], kde=True, bins=100)
plt.title('Total Energy Distribution')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Laptop World\Building_Energy_Twin_Sequential_3Years.csv", parse_dates=['Timestamp'], index_col='Timestamp')

plt.figure(figsize=(12, 6))
sns.histplot(df['Energy_HVAC_Wh'], kde=True, bins=100)
plt.title('HVAC Distribution')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Laptop World\Building_Energy_Twin_Sequential_3Years.csv", parse_dates=['Timestamp'], index_col='Timestamp')

plt.figure(figsize=(12, 6))
sns.histplot(df['Energy_Plug_Wh'], kde=True, bins=100)
plt.title('Plug Distribution')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Laptop World\Building_Energy_Twin_Sequential_3Years.csv", parse_dates=['Timestamp'], index_col='Timestamp')

plt.figure(figsize=(12, 6))
sns.histplot(df['Energy_Lighting_Wh'], kde=True, bins=100)
plt.title('Lighting Distribution')
plt.show()
